# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///vbo.db

# %%
# %%sql
# SELECT*FROM Customers LIMIT 3;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico')]

# %%
#ORDERS TABLOSUNDAKİ MÜSTERİ SAYISI

# %%
# %%sql
# SELECT*FROM Orders  LIMIT 10;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(10248, 90, 5, '4.07.1996', 3),
#  (10249, 81, 6, '5.07.1996', 1),
#  (10250, 34, 4, '8.07.1996', 2),
#  (10251, 84, 3, '8.07.1996', 1),
#  (10252, 76, 4, '9.07.1996', 2),
#  (10253, 34, 3, '10.07.1996', 2),
#  (10254, 14, 5, '11.07.1996', 2),
#  (10255, 68, 9, '12.07.1996', 3),
#  (10256, 88, 3, '15.07.1996', 2),
#  (10257, 35, 4, '16.07.1996', 3)]

# %%
# %%sql
# SELECT COUNT(CustomerID) FROM Orders;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(196,)]

# %%
#ORDER TABLOSUNDAKİ EŞŞİZ MÜŞTERİLER

# %%
# %%sql
# SELECT COUNT(DISTINcT CustomerID) FROM Orders;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(74,)]

# %%
##CUSTOMERS TABLOSUNDA HANGİ ÜLKEDEN KAÇAR MÜŞTERİ VAR?

# %%
# %%sql
# SELECT COUNT(CustomerID) AS POİNT, Country FROM Customers GROUP BY Country;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Argentina'),
#  (2, 'Austria'),
#  (2, 'Belgium'),
#  (9, 'Brazil'),
#  (3, 'Canada'),
#  (2, 'Denmark'),
#  (2, 'Finland'),
#  (11, 'France'),
#  (11, 'Germany'),
#  (1, 'Ireland'),
#  (3, 'Italy'),
#  (5, 'Mexico'),
#  (1, 'Norway'),
#  (1, 'Poland'),
#  (2, 'Portugal'),
#  (5, 'Spain'),
#  (2, 'Sweden'),
#  (2, 'Switzerland'),
#  (7, 'UK'),
#  (13, 'USA'),
#  (4, 'Venezuela')]

# %%
# %%sql
# SELECT*FROM Customers WHERE Country ="Brazil" OR Country = "USA";
# Out:
#  * sqlite:///vbo.db
# Done.
# [(15, 'Comércio Mineiro', 'Pedro Afonso', 'Av. dos Lusíadas, 23', 'São Paulo', '05432-043', 'Brazil'),
#  (21, 'Familia Arquibaldo', 'Aria Cruz', 'Rua Orós, 92', 'São Paulo', '05442-030', 'Brazil'),
#  (31, 'Gourmet Lanchonetes', 'André Fonseca', 'Av. Brasil, 442', 'Campinas', '04876-786', 'Brazil'),
#  (32, 'Great Lakes Food Market', 'Howard Snyder', '2732 Baker Blvd.', 'Eugene', '97403', 'USA'),
#  (34, 'Hanari Carnes', 'Mario Pontes', 'Rua do Paço, 67', 'Rio de Janeiro', '05454-876', 'Brazil'),
#  (36, 'Hungry Coyote Import Store', 'Yoshi Latimer', 'City Center Plaza 516 Main St.', 'Elgin', '97827', 'USA'),
#  (43, 'Lazy K Kountry Store', 'John Steel', '12 Orchestra Terrace', 'Walla Walla', '99362', 'USA'),
#  (45, "Let's Stop N Shop", 'Jaime Yorres', '87 Polk St. Suite 5', 'San Francisco', '94117', 'USA'),
#  (48, 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA'),
# ...

# %%
# Önce ülkeye sonra şehre göre group by işlemi yapıp bu kırılımda müşteri sayısını bulunuz.

# %%
# %%sql
# SELECT COUNT(CustomerID) Country,City FROM Customers GROUP BY Country,
# City;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3, 'Buenos Aires'),
#  (1, 'Graz'),
#  (1, 'Salzburg'),
#  (1, 'Bruxelles'),
#  (1, 'Charleroi'),
#  (1, 'Campinas'),
#  (1, 'Resende'),
#  (3, 'Rio de Janeiro'),
#  (4, 'São Paulo'),
#  (1, 'Montréal'),
#  (1, 'Tsawassen'),
#  (1, 'Vancouver'),
#  (1, 'København'),
#  (1, 'Århus'),
#  (1, 'Helsinki'),
#  (1, 'Oulu'),
#  (1, 'Lille'),
#  (1, 'Lyon'),
#  (1, 'Marseille'),
#  (2, 'Nantes'),
#  (2, 'Paris'),
#  (1, 'Reims'),
#  (1, 'Strasbourg'),
#  (1, 'Toulouse'),
#  (1, 'Versailles'),
#  (1, 'Aachen'),
#  (1, 'Berlin'),
#  (1, 'Brandenburg'),
#  (1, 'Cunewalde'),
#  (1, 'Frankfurt a.M.'),
#  (1, 'Köln'),
#  (1, 'Leipzig'),
#  (1, 'Mannheim'),
#  (1, 'München'),
#  (1, 'Münster'),
#  (1, 'Stuttgart'),
#  (1, 'Cork'),
#  (1, 'Bergamo'),
#  (1, 'Reggio Emilia'),
#  (1, 'Torino'),
#  (5, 'México D.F.'),
#  (1, 'Stavern'),
#  (1, 'Walla'),
#  (2, 'Lisboa'),
#  (1, 'Barcelona'),
#  (3, 'Madrid'),
#  (1, 'Sevilla'),
#  (1, 'Bräcke'),
#  (1, 'Luleå'),
# ...

# %%
#Müşteriler adreslerinin herhangi bir yerinde "da " ifadesi geçen tüm adresler

# %%
# %%sql
# SELECT*FROM Customers WHERE Address LIKE '%da%';
# Out:
#  * sqlite:///vbo.db
# Done.
# [(2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (13, 'Centro comercial Moctezuma', 'Francisco Chang', 'Sierras de Granada 9993', 'México D.F.', '5022', 'Mexico'),
#  (15, 'Comércio Mineiro', 'Pedro Afonso', 'Av. dos Lusíadas, 23', 'São Paulo', '05432-043', 'Brazil'),
#  (28, 'Furia Bacalhau e Frutos do Mar', 'Lino Rodriguez', 'Jardim das rosas n. 32', 'Lisboa', '1675', 'Portugal'),
#  (54, 'Océano Atlántico Ltda.', 'Yvonne Moncada', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'Buenos Aires', '1010', 'Argentina'),
#  (60, 'Princesa Isabel Vinhoss', 'Isabel de Castro', 'Estrada da saúde n. 58', 'Lisboa', '1756', 'Portugal'),
#  (61, 'Que Delícia', 'Bernardo Batista', 'Rua da Panificadora, 12', 'Rio de Janeiro', '02389-673', 'Brazil'),
#  (62, 'Queen Cozinha', 'Lúcia Carvalho', 'Alameda dos Canàrios, 891', 'São Paulo', '05487-020', 'Brazil'),
# ...

# %%
 # Germany-Berlin'de yaşayan müşteri/müşterilerin isimleri nelerdir?

# %%
# %%sql
# SELECT CustomerName FROM Customers  WHERE Country= "Germany" AND City = "Berlin";
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Alfreds Futterkiste',)]

# %%
 # Canada'da yaşayıp isimlerinde "in" ifadesi geçen müşteri/müşterileri bulunuz.

# %%
# %%sql
# SELECT*FROM Customers WHERE CustomerName LIKE "%in%";
# Out:
#  * sqlite:///vbo.db
# Done.
# [(14, 'Chop-suey Chinese', 'Yang Wang', 'Hauptstr. 29', 'Bern', '3012', 'Switzerland'),
#  (15, 'Comércio Mineiro', 'Pedro Afonso', 'Av. dos Lusíadas, 23', 'São Paulo', '05432-043', 'Brazil'),
#  (16, 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12 Brewery', 'London', 'WX1 6LT', 'UK'),
#  (22, 'FISSA Fabrica Inter. Salchichas S.A.', 'Diego Roel', 'C/ Moralzarzal, 86', 'Madrid', '28034', 'Spain'),
#  (30, 'Godos Cocina Típica', 'José Pedro Freyre', 'C/ Romero, 33', 'Sevilla', '41101', 'Spain'),
#  (38, 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK'),
#  (42, 'Laughing Bacchus Wine Cellars', 'Yoshi Tannamuri', '1900 Oak St.', 'Vancouver', 'V3F 2K1', 'Canada'),
#  (47, 'LINO-Delicateses', 'Felipe Izquierdo', 'Ave. 5 de Mayo Porlamar', 'I. de Margarita', '4980', 'Venezuela'),
#  (48, 'Lonesome Pine Restaurant', 'Fran Wilson', '89 Chiaroscuro Rd.', 'Portland', '97219', 'USA'),
# ...

# %%
# Fiyatı 40 TL ile 90 TL arasında olan ürünlerin isimleri ve fiyatları nelerdir?

# %%
# %%sql
# SELECT ProductName, Price FROM Products WHERE Price<90 AND Price>40;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Genen Shouyu', 43),
#  ('Carnarvon Tigers', 62),
#  ('Teatime Chocolate Biscuits', 43),
#  ("Sir Rodney's Marmalade", 81),
#  ('Guaraná Fantástica', 43),
#  ('Schoggi Schokolade', 43),
#  ('Rössle Sauerkraut', 45),
#  ('Geitost', 43),
#  ('Boston Crab Meat', 43),
#  ('Ipoh Coffee', 46),
#  ('Røgede sild', 43),
#  ('Zaanse koeken', 43),
#  ('Manjimup Dried Apples', 53),
#  ('Ravioli Angelo', 43),
#  ('Raclette Courdavault', 55),
#  ("Sirop d'érable", 43),
#  ('Tarte au sucre', 49),
#  ('Vegie-spread', 43),
#  ('Louisiana Fiery Hot Pepper Sauce', 43),
#  ('Scottish Longbreads', 45)]

# %%
# Fiyatı 30 TL'den büyük olan ürünlerin isimlerini, fiyatlarını ve fiyatlarının karesini bulunuz ve tüm değişkenlerin isimlendirmelerini aşağıdaki şekilde yapınız:

# urun ismi, urun_fiyati, ürün_fiyatinin_karesi

# %%
# %%sql
# SELECT ProductName AS ÜRÜN_İSMİ, Price AS Fiyat, Price*Price AS Karesi FROM Products WHERE Price>30;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Northwoods Cranberry Sauce', 40, 1600),
#  ('Mishi Kobe Niku', 97, 9409),
#  ('Ikura', 31, 961),
#  ('Queso Manchego La Pastora', 38, 1444),
#  ('Genen Shouyu', 43, 1849),
#  ('Alice Mutton', 39, 1521),
#  ('Carnarvon Tigers', 62, 3844),
#  ('Teatime Chocolate Biscuits', 43, 1849),
#  ("Sir Rodney's Marmalade", 81, 6561),
#  ('Guaraná Fantástica', 43, 1849),
#  ('Gumbär Gummibärchen', 31, 961),
#  ('Schoggi Schokolade', 43, 1849),
#  ('Rössle Sauerkraut', 45, 2025),
#  ('Thüringer Rostbratwurst', 123, 15129),
#  ('Gorgonzola Telino', 435, 189225),
#  ('Mascarpone Fabioli', 32, 1024),
#  ('Geitost', 43, 1849),
#  ('Côte de Blaye', 263, 69169),
#  ('Boston Crab Meat', 43, 1849),
#  ('Ipoh Coffee', 46, 2116),
#  ('Røgede sild', 43, 1849),
#  ('Zaanse koeken', 43, 1849),
#  ('Manjimup Dried Apples', 53, 2809),
#  ('Perth Pasties', 32, 1024),
#  ('Gnocchi di nonna Alice', 38, 1444),
#  ('Ravioli Angelo', 43, 1849),
#  ('Raclette Courdavault', 55, 3025),
# ...

# %%
# Products tablosundaki CategoryID’lerin yani kategorilerin isimleri nelerdir?

# %%
# %%sql
# SELECT ProductName, CategoryID FROM Products;
# Out:
#  * sqlite:///vbo.db
# Done.
# [('Chais', 1),
#  ('Chang', 1),
#  ('Aniseed Syrup', 2),
#  ("Chef Anton's Cajun Seasoning", 2),
#  ("Chef Anton's Gumbo Mix", 2),
#  ("Grandma's Boysenberry Spread", 2),
#  ("Uncle Bob's Organic Dried Pears", 7),
#  ('Northwoods Cranberry Sauce', 2),
#  ('Mishi Kobe Niku', 6),
#  ('Ikura', 8),
#  ('Queso Cabrales', 4),
#  ('Queso Manchego La Pastora', 4),
#  ('Konbu', 8),
#  ('Tofu', 7),
#  ('Genen Shouyu', 2),
#  ('Pavlova', 3),
#  ('Alice Mutton', 6),
#  ('Carnarvon Tigers', 8),
#  ('Teatime Chocolate Biscuits', 3),
#  ("Sir Rodney's Marmalade", 3),
#  ("Sir Rodney's Scones", 3),
#  ("Gustaf's Knäckebröd", 5),
#  ('Tunnbröd', 5),
#  ('Guaraná Fantástica', 1),
#  ('NuNuCa Nuß-Nougat-Creme', 3),
#  ('Gumbär Gummibärchen', 3),
#  ('Schoggi Schokolade', 3),
#  ('Rössle Sauerkraut', 7),
#  ('Thüringer Rostbratwurst', 6),
#  ('Nord-Ost Matjeshering', 8),
#  ('Gorgonzola Telino', 4),
#  ('Mascarpone Fabioli', 4),
#  ('Geitost', 4),
#  ('Sasquatch Ale', 1),
# ...

# %%
# %%sql
# SELECT *
# FROM Products
# LEFT JOIN Categories on Products.CategoryID = Categories.CategoryID;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(1, 'Chais', 1, 1, '10 boxes x 20 bags', 18, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (2, 'Chang', 1, 1, '24 - 12 oz bottles', 19, 1, 'Beverages', 'Soft drinks, coffees, teas, beers, and ales'),
#  (3, 'Aniseed Syrup', 1, 2, '12 - 550 ml bottles', 10, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (4, "Chef Anton's Cajun Seasoning", 2, 2, '48 - 6 oz jars', 22, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (5, "Chef Anton's Gumbo Mix", 2, 2, '36 boxes', 21, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (6, "Grandma's Boysenberry Spread", 3, 2, '12 - 8 oz jars', 25, 2, 'Condiments', 'Sweet and savory sauces, relishes, spreads, and seasonings'),
#  (7, "Uncle Bob's Organic Dried Pears", 3, 7, '12 - 1 lb pkgs.', 30, 7, 'Produce', 'Dried fruit and bean curd'),
# ...

# %%
# beverages ürün kategorisindeki ürünlerin fiyat ortalaması nedir?

# %%
# %%sql
# SELECT AVG(Price) FROM Products WHERE CategoryID =1;
# Out:
#  * sqlite:///vbo.db
# Done.
# [(42.75,)]

# %%
# %%sql
# SELECT AVG(Price)
# FROM Products
# LEFT JOIN Categories on Products.CategoryID = categories.CategoryID
# WHERE CategoryName = 'Beverages';
# Out:
#  * sqlite:///vbo.db
# Done.
# [(42.75,)]

# %%
# USA'de yaşayan müşterilerin kazandırdığı toplam kazancı bulunuz.

# %%
# %%sql
# SELECT SUM(p.Price)
# FROM Orders o
# LEFT JOIN OrderDetails od on o.OrderID = od.OrderID
# LEFT JOIN Products p on od.ProductID = p.ProductID
# LEFT JOIN Customers cu on o.CustomerID = cu.CustomerID where cu.Country = 'USA';
# Out:
#  * sqlite:///vbo.db
# Done.
# [(3762,)]
